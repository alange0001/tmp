# %%
import getgraph

# %% [markdown]
# # 1. From vm3 to seqadmal
#
# * vm3: https://www.lange.net.br/carregar_link (300MB)
# * seqadmal:
#   * IPv4: 200.181.121.148 (NAT)
#   * IPv6: 2804:d59:5102:2502:2c6f:8af6:2046:d00c
#
# NOTE: See .log files for more details.

# %% [markdown]
# ### IPv4

# %%
getgraph.plot_file('from_vm3-to_seqadmal-ipv4.nethogs.log', type='nethogs', nethogs_max_t=350)
# Out:
# Average: 0.7407691323723588

# %% [markdown]
# ### IPv6

# %%
getgraph.plot_file('from_vm3-to_seqadmal-ipv6.nethogs.log', type='nethogs')
# Out:
# Average: 0.0074687623541039175

# %% [markdown]
# # 2. From ubuntu to seqadmal
#
# * Ubuntu: https://releases.ubuntu.com/20.04.2.0/ubuntu-20.04.2.0-desktop-amd64.iso

# %% [markdown]
# ### IPv4

# %%
getgraph.plot_file('from_ubuntu-to_seqadmal-ipv4.nethogs.log', type='nethogs')
# Out:
# Average: 3.7201035853794657

# %% [markdown]
# ### IPv6

# %%
getgraph.plot_file('from_ubuntu-to_seqadmal-ipv6.nethogs.log', type='nethogs')
# Out:
# Average: 0.8236090332031251

# %% [markdown]
# # 3. From c3sl to seqadmal
#
# * c3sl: http://debian.c3sl.ufpr.br/debian-cd/current/amd64/iso-dvd/debian-10.9.0-amd64-DVD-1.iso

# %% [markdown]
# ### IPv4

# %%
getgraph.plot_file('from_c3sl-to_seqadmal-ipv4.nethogs.log', type='nethogs')
# Out:
# Average: 0.8036316499255955

# %% [markdown]
# ### IPv6

# %%
getgraph.plot_file('from_c3sl-to_seqadmal-ipv6.nethogs.log', type='nethogs')
# Out:
# Average: 0.8416180710565475

# %% [markdown]
# # 4. From vm3 to google compute instance (São Paulo)
#
# * vm3: http://www.lange.net.br/carregar_link2 (3.7 GiB)
# * google compute instance: Type e2-micro, Zone southamerica-east1-c
#
# ### IPv4

# %%
getgraph.plot_file('from_vm3-to_google_sp-ipv4.nethogs.log', type='nethogs')
# Out:
# Average: 2.3500435732886906
